# %% [markdown]
# ## Instalação Spark

# %%
pip install findspark
# Out:
# Requirement already satisfied: findspark in c:\users\brsantan\anaconda3\lib\site-packages (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .master('local[*]') \
    .appName("Desafio-de-Qualidade")

# %%
spark

# %% [markdown]
# ## Importando os CSV

# %%
import re
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, FloatType

# %%
#Schema dos datasets

schema_airports = StructType([
    StructField("faa",  StringType(),  True),
    StructField("name", StringType(),  True),
    StructField("lat",  FloatType(),   True),
    StructField("lon",  FloatType(),   True),
    StructField("alt",  IntegerType(), True),
    StructField("tz",   IntegerType(), True),
    StructField("dst",  StringType(),  True)
])

schema_planes = StructType([
    StructField("tailnum",      StringType(),  True),
    StructField("year",         IntegerType(), True),
    StructField("type",         StringType(),  True),
    StructField("manufacturer", StringType(),  True),
    StructField("model",        StringType(),  True),
    StructField("engines",      IntegerType(), True),
    StructField("seats",        IntegerType(), True),
    StructField("speed",        IntegerType(), True),
    StructField("engine",       StringType(),  True)
])

schema_flights = StructType([
    StructField("year",      IntegerType(), True),
    StructField("month",     IntegerType(), True),
    StructField("day",       IntegerType(), True),
    StructField("dep_time",  StringType(),  True),
    StructField("dep_delay", IntegerType(), True),
    StructField("arr_time",  StringType(),  True),
    StructField("arr_delay", IntegerType(), True),
    StructField("carrier",   StringType(),  True),
    StructField("tailnum",   StringType(),  True),
    StructField("flight",    StringType(),  True),
    StructField("origin",    StringType(),  True),
    StructField("dest",      StringType(),  True),
    StructField("air_time",  IntegerType(), True),
    StructField("distance",  IntegerType(), True),
    StructField("hour",      IntegerType(), True),
    StructField("minute",    IntegerType(), True),
])

# %%
#Criando os Data Frame

df_airports = (spark.getOrCreate().read
                  .format("csv")
                  .option("header", "true")
                  .schema(schema_airports)
                  .load("../data/airports.csv"))

df_planes = (spark.getOrCreate().read
                  .format("csv")
                  .option("header", "true")
                  .schema(schema_planes)
                  .load("../data/planes.csv"))

df_flights = (spark.getOrCreate().read
                  .format("csv")
                  .option("header", "true")
                  .schema(schema_flights)
                  .load("../data/flights.csv"))

# %%
df_flights = df_flights[['year', 'month', 'day','hour', 'minute','dep_time','arr_time', 'dep_delay', 'arr_delay', 'carrier', 'tailnum', 'flight',
        'origin','dest', 'air_time', 'distance']]

# %% [markdown]
# # <center> Regex Comuns

# %%
REGEX_ALPHA    = r'[a-zA-Z]+'
REGEX_INTEGER  = r'[0-9]+'
REGEX_FLOAT    = r'[0-9]+\.[0-9]+'
REGEX_ALPHANUM = r'[0-9a-zA-Z]+'
REGEX_EMPTY_STR= r'[\t ]+$'
REGEX_SPECIAL  = r'[!@#$%&*\(\)_]+'
REGEX_NNUMBER  = r'^N[1-9][0-9]{2,3}([ABCDEFGHJKLMNPRSTUVXWYZ]{1,2})'
REGEX_NNUMBER_INVALID = r'(N0.*$)|(.*[IO].*)'
REGEX_TIME_FMT = r'^(([0-1]?[0-9])|(2[0-3]))([0-5][0-9])$'

# %% [markdown]
# # <Center> DataSet Airports

# %% [markdown]
# # <center> Pergunta 1

# %%
df_airports.filter(df_airports["faa"].rlike("[\w{3,5}]")).show()
# Out:
# +---+--------------------+---------+-----------+----+---+---+
# |faa|                name|      lat|        lon| alt| tz|dst|
# +---+--------------------+---------+-----------+----+---+---+
# |04G|   Lansdowne Airport|41.130474|  -80.61958|1044| -5|  A|
# |06A|Moton Field Munic...| 32.46057|  -85.68003| 264| -5|  A|
# |06C| Schaumburg Regional| 41.98934|  -88.10124| 801| -6|  A|
# |06N|     Randall Airport| 41.43191|  -74.39156| 523| -5|  A|
# |09J|Jekyll Island Air...|31.074472|  -81.42778|  11| -4|  A|
# |0A9|Elizabethton Muni...|36.371223| -82.173416|1593| -4|  A|
# |0G6|Williams County A...|41.467304| -84.506775| 730| -5|  A|
# |0G7|Finger Lakes Regi...|42.883564| -76.781235| 492| -5|  A|
# |0P2|Shoestring Aviati...|39.794823| -76.647194|1000| -5|  U|
# |0S9|Jefferson County ...| 48.05381|-122.810646| 108| -8|  A|
# |0W3|Harford County Ai...|39.566837|   -76.2024| 409| -5|  A|
# |10C|  Galt Field Airport| 42.40289| -88.375114| 875| -6|  U|
# |17G|Port Bucyrus-Craw...|40.781555|  -82.97481|1003| -5|  A|
# |19A|Jackson County Ai...|34.175865|   -83.5616| 951| -4|  U|
# |1A3|Martin Campbell F...|35.015804|  -84.34683|1789| -4|  A|
# |1B9| Mansfield Municipal|42.000134|  -71.19677| 122| -5|  A|
# |1C9|Frazier Lake Airpark|54.013332| -124.76833| 152| -8|  A|
# |1CS|Clow Internationa...|41.695976| -88.129234| 670| -6|  U|
# |1G3|  Kent State Airport| 41.15139|  -81.41511|1134| -4|  A|
# |1OH|     Fortman Airport|40.555325|  -84.38662| 885| -5|  U|
# +---+--------------------+---------+-----------+----+---+---+
# only showing top 20 rows

# %%
df_airports.filter(df_airports["faa"].rlike("[\w{3,5}]")).count()
# Out:
# 1397

# %%
df_airports = df_airports.withColumn(
    "qa_faa", 
         (
             F.when(F.col("faa").isNull(), "M")
              .when(F.col("faa").rlike("^(\w{3,5})"), "F")
         )
    )

# %% [markdown]
# # <center> Pergunta 2

# %%
df_airports = df_airports.withColumn(
    "qa_name", 
         F.when(df_airports["name"].isNull(), "M")
    )

# %%
df_airports.show()
# Out:
# +---+--------------------+---------+-----------+----+---+---+------+-------+
# |faa|                name|      lat|        lon| alt| tz|dst|qa_faa|qa_name|
# +---+--------------------+---------+-----------+----+---+---+------+-------+
# |04G|   Lansdowne Airport|41.130474|  -80.61958|1044| -5|  A|     F|   null|
# |06A|Moton Field Munic...| 32.46057|  -85.68003| 264| -5|  A|     F|   null|
# |06C| Schaumburg Regional| 41.98934|  -88.10124| 801| -6|  A|     F|   null|
# |06N|     Randall Airport| 41.43191|  -74.39156| 523| -5|  A|     F|   null|
# |09J|Jekyll Island Air...|31.074472|  -81.42778|  11| -4|  A|     F|   null|
# |0A9|Elizabethton Muni...|36.371223| -82.173416|1593| -4|  A|     F|   null|
# |0G6|Williams County A...|41.467304| -84.506775| 730| -5|  A|     F|   null|
# |0G7|Finger Lakes Regi...|42.883564| -76.781235| 492| -5|  A|     F|   null|
# |0P2|Shoestring Aviati...|39.794823| -76.647194|1000| -5|  U|     F|   null|
# |0S9|Jefferson County ...| 48.05381|-122.810646| 108| -8|  A|     F|   null|
# |0W3|Harford County Ai...|39.566837|   -76.2024| 409| -5|  A|     F|   null|
# |10C|  Galt Field Airport| 42.40289| -88.375114| 875| -6|  U|     F|   null|
# |17G|Port Bucyrus-Craw...|40.781555|  -82.97481|1003| -5|  A|     F|   null|
# |19A|Jackson County Ai...|34.175865|   -83.5616| 951| -4|  U|     F|   null|
# |1A3|Martin Campbell F...|35.015804|  -84.34683|1789| -4|  A|     F|   null|
# |1B9| Mansfield Municipal|42.000134|  -71.19677| 122| -5|  A|     F|   null|
# |1C9|Frazier Lake Airpark|54.013332| -124.76833| 152| -8|  A|     F|   null|
# |1CS|Clow Internationa...|41.695976| -88.129234| 670| -6|  U|     F|   null|
# |1G3|  Kent State Airport| 41.15139|  -81.41511|1134| -4|  A|     F|   null|
# |1OH|     Fortman Airport|40.555325|  -84.38662| 885| -5|  U|     F|   null|
# +---+--------------------+---------+-----------+----+---+---+------+-------+
# only showing top 20 rows

# %% [markdown]
# # <center> Pergunta 3

# %%
df_airports = df_airports.withColumn(
    "qa_lat", 
         F.when(df_airports["lat"].isNull(), "M")
          .when(~df_airports["lat"].between(-180,180), "I")
          .when(~df_airports["lat"].rlike("\d"), "A")
    )

# %%
df_airports.filter(df_airports.qa_lat.isNotNull()).show()
# Out:
# +---+----+---+---+---+---+---+------+-------+------+
# |faa|name|lat|lon|alt| tz|dst|qa_faa|qa_name|qa_lat|
# +---+----+---+---+---+---+---+------+-------+------+
# +---+----+---+---+---+---+---+------+-------+------+

# %% [markdown]
# # <center> Pergunta 4

# %%
df_airports = df_airports.withColumn(
    "qa_lon", 
         F.when(F.col("lon").isNull(), "M")
          .when(~F.col("lon").between(-180,180), "I")
          .when(~F.col("lon").rlike("\d"), "A")
    )

# %%
df_airports.filter(df_airports.qa_lon.isNotNull()).show()
# Out:
# +---+----+---+---+---+---+---+------+-------+------+------+
# |faa|name|lat|lon|alt| tz|dst|qa_faa|qa_name|qa_lat|qa_lon|
# +---+----+---+---+---+---+---+------+-------+------+------+
# +---+----+---+---+---+---+---+------+-------+------+------+

# %%
df_airports.show()
# Out:
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+------+
# |faa|                name|      lat|        lon| alt| tz|dst|qa_faa|qa_name|qa_lat|qa_lon|
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+------+
# |04G|   Lansdowne Airport|41.130474|  -80.61958|1044| -5|  A|     F|   null|  null|  null|
# |06A|Moton Field Munic...| 32.46057|  -85.68003| 264| -5|  A|     F|   null|  null|  null|
# |06C| Schaumburg Regional| 41.98934|  -88.10124| 801| -6|  A|     F|   null|  null|  null|
# |06N|     Randall Airport| 41.43191|  -74.39156| 523| -5|  A|     F|   null|  null|  null|
# |09J|Jekyll Island Air...|31.074472|  -81.42778|  11| -4|  A|     F|   null|  null|  null|
# |0A9|Elizabethton Muni...|36.371223| -82.173416|1593| -4|  A|     F|   null|  null|  null|
# |0G6|Williams County A...|41.467304| -84.506775| 730| -5|  A|     F|   null|  null|  null|
# |0G7|Finger Lakes Regi...|42.883564| -76.781235| 492| -5|  A|     F|   null|  null|  null|
# |0P2|Shoestring Aviati...|39.794823| -76.647194|1000| -5|  U|     F|   null|  null|  null|
# |0S9|Jefferson County ...| 48.05381|-122.810646| 108| -8|  A|     F|   null|  null|  null|
# |0W3|Harford County Ai...|39.566837|   -76.2024| 409| -5|  A|     F|   null|  null|  null|
# |10C|  Galt Field Airport| 42.40289| -88.375114| 875| -6|  U|     F|   null|  null|  null|
# |17G|Port Bucyrus-Craw...|40.781555|  -82.97481|1003| -5|  A|     F|   null|  null|  null|
# |19A|Jackson County Ai...|34.175865|   -83.5616| 951| -4|  U|     F|   null|  null|  null|
# |1A3|Martin Campbell F...|35.015804|  -84.34683|1789| -4|  A|     F|   null|  null|  null|
# |1B9| Mansfield Municipal|42.000134|  -71.19677| 122| -5|  A|     F|   null|  null|  null|
# |1C9|Frazier Lake Airpark|54.013332| -124.76833| 152| -8|  A|     F|   null|  null|  null|
# |1CS|Clow Internationa...|41.695976| -88.129234| 670| -6|  U|     F|   null|  null|  null|
# |1G3|  Kent State Airport| 41.15139|  -81.41511|1134| -4|  A|     F|   null|  null|  null|
# |1OH|     Fortman Airport|40.555325|  -84.38662| 885| -5|  U|     F|   null|  null|  null|
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+------+
# only showing top 20 rows

# %% [markdown]
# # <center> Pergunta 5

# %%
df_airports = df_airports.withColumn(
    "qa_alt", 
           F.when(F.col("alt").isNull(), "M")
            .when(F.col("alt") < 0, "I")
            .when(~F.col("alt").rlike("\d"), "A")
      )
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34732/43465505.py in <module>
# ----> 1 df_airports = df_airports.withColumn(
#       2     "qa_alt",
#       3            F.when(F.col("alt").isNull(), "M")
#       4             .when(F.col("alt") < 0, "I")
#       5             .when(~F.col("alt").rlike("\d"), "A")
#
# C:\spark-3.2.1-bin-hadoop2.7\python\pyspark\sql\dataframe.py in withColumn(self, colName, col)
#    2476         if not isinstance(col, Column):
#    2477             raise TypeError("col should be Column")
# -> 2478         return DataFrame(self._jdf.withColumn(colName, col._jc), self.sql_ctx)
#    2479
#    2480     def withColumnRenamed(self, existing, new):
#
# C:\spark-3.2.1-bin-hadoop2.7\python\lib\py4j-0.10.9.3-src.zip\py4j\java_gateway.py in __call__(self, *args)
#    1319
#    1320         answer = self.gateway_client.send_command(command)
# -> 1321         return_value = get_return_value(
#    1322             answer, self.gateway_client, self.target_id, self.name)
#    1323
#
# C:\spark-3.2.1-bin-hadoop2.7\python\pyspark\sql\utils.py in deco(*a, **kw)
#     115                 # Hide where the exception came from that shows a non-Pythonic
#     116                 # JVM exception message.
# --> 117                 raise converted from None
#     118             else:
#     119                 raise
#
# AnalysisException: cannot resolve 'alt' given input columns: [faa, qa_dst, qa_faa, qa_lat, qa_lon, qa_name, qa_tz];
# 'Project [faa#0, qa_faa#80, qa_name#89, qa_lat#99, qa_lon#110, qa_tz#122, qa_dst#135, CASE WHEN isnull('alt) THEN M WHEN ('alt < 0) THEN I WHEN NOT RLIKE('alt, \d) THEN A END AS qa_alt#717]
# +- Project [faa#0, qa_faa#80, qa_name#89, qa_lat#99, qa_lon#110, qa_tz#122, qa_dst#135]
#    +- Project [faa#0, name#1, lat#2, lon#3, alt#4, tz#5, dst#6, qa_faa#80, qa_name#89, qa_lat#99, qa_lon#110, qa_tz#122, CASE WHEN isnull(dst#6) THEN M WHEN RLIKE(dst#6, E, A, S, O, Z, N, U) THEN C WHEN RLIKE(dst#6, \d) THEN N END AS qa_dst#135]
#       +- Project [faa#0, name#1, lat#2, lon#3, alt#4, tz#5, dst#6, qa_faa#80, qa_name#89, qa_lat#99, qa_lon#110, CASE WHEN isnull(tz#5) THEN M WHEN NOT ((tz#5 >= -11) AND (tz#5 <= 14)) THEN I WHEN NOT RLIKE(cast(tz#5 as string), \d) THEN A END AS qa_tz#122]
#          +- Project [faa#0, name#1, lat#2, lon#3, alt#4, tz#5, dst#6, qa_faa#80, qa_name#89, qa_lat#99, CASE WHEN isnull(lon#3) THEN M WHEN NOT ((lon#3 >= cast(-180 as float)) AND (lon#3 <= cast(180 as float))) THEN I WHEN NOT RLIKE(cast(lon#3 as string), \d) THEN A END AS qa_lon#110]
#             +- Project [faa#0, name#1, lat#2, lon#3, alt#4, tz#5, dst#6, qa_faa#80, qa_name#89, CASE WHEN isnull(lat#2) THEN M WHEN NOT ((lat#2 >= cast(-180 as float)) AND (lat#2 <= cast(180 as float))) THEN I WHEN NOT RLIKE(cast(lat#2 as string), \d) THEN A END AS qa_lat#99]
#                +- Project [faa#0, name#1, lat#2, lon#3, alt#4, tz#5, dst#6, qa_faa#80, CASE WHEN isnull(name#1) THEN M END AS qa_name#89]
#                   +- Project [faa#0, name#1, lat#2, lon#3, alt#4, tz#5, dst#6, CASE WHEN isnull(faa#0) THEN M WHEN RLIKE(faa#0, ^(\w{3,5})) THEN F END AS qa_faa#80]
#                      +- Relation [faa#0,name#1,lat#2,lon#3,alt#4,tz#5,dst#6] csv

# %%
df_airport.filter(df_airport.qa_alt.isNotNull()).show()

# %%
df_airport.show(1400)

# %% [markdown]
# # <center> Pergunta 6

# %%
df_airports = df_airports.withColumn(
    "qa_tz", 
         F.when(F.col("tz").isNull(), "M")
          .when(~F.col("tz").between(-11,14), "I")
          .when(~F.col("tz").rlike("\d"), "A")
    )

# %%
df_airports.show(1400)
# Out:
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+------+-----+
# |ANC|Ted Stevens Ancho...|61.174362| -149.99637| 152| -9|  A|     F|   null|  null|  null| null|
# |AND|       Anderson Rgnl|34.494583|  -82.70939| 782| -5|  A|     F|   null|  null|  null| null|
# |ANI|       Aniak Airport|  61.5816|   -159.543|  88| -9|  A|     F|   null|  null|  null| null|
# |ANN|      Annette Island|55.042435| -131.57224| 119| -9|  A|     F|   null|  null|  null| null|
# |ANP|         Lee Airport| 38.94278|  -76.56834|  34| -5|  A|     F|   null|  null|  null| null|
# |ANQ|Tri-State Steuben...|41.639698| -85.083496| 995| -5|  A|     F|   null|  null|  null| null|
# |ANV|       Anvik Airport|  62.6467|   -160.191| 309| -9|  A|     F|   null|  null|  null| null|
# |AOH|Lima Allen County...|40.707478|  -84.02708| 975| -5|  A|     F|   null|  null|  null| null|
# |AOO|    Altoona Blair Co| 40.29637|  -78.32002|1504| -5|  A|     F|   null|  null|  null| null|
# |AOS|Amook Bay Seaplan...| 57.47139| -153.81528|   0| -9|  A|     F|   null|  null|  null| null|
# |APA|          Centennial| 39.57013|  -104.8493|5883| -7|  A|     F|   null|  null|  null| null|
# |APC| Napa County Airport|38.213196| -122.28069|  35| -7|  A|     F|   null|  null|  null| null|
# |APF|         Naples Muni|26.152618|  -81.77529|   8| -5|  A|     F|   null|  null|  null| null|
# |APG|        Phillips Aaf| 39.46622|  -76.16881|  57| -5|  A|     F|   null|  null|  null| null|
# |APN|Alpena County Reg...|  45.0781|   -83.5603| 689| -5|  A|     F|   null|  null|  null| null|
# |AQC|Klawock Seaplane ...|55.554657|  -133.1017|   0| -9|  A|     F|   null|  null|  null| null|
# |ARA|       Acadiana Rgnl|30.037758| -91.883896|  24| -6|  A|     F|   null|  null|  null| null|
# |ARB|Ann Arbor Municip...|42.132275|  -83.44442| 839| -5|  A|     F|   null|  null|  null| null|
# |ARC|Arctic Village Ai...|  68.1147|   -145.579|2092| -9|  A|     F|   null|  null|  null| null|
# |ART|      Watertown Intl| 43.99192| -76.021736| 325| -5|  A|     F|   null|  null|  null| null|
# |ARV|            Lakeland|45.927776| -89.730835|1629| -6|  A|     F|   null|  null|  null| null|
# |ASE|Aspen Pitkin Coun...|  39.2232|   -106.869|7820| -7|  A|     F|   null|  null|  null| null|
# |ASH| Boire Field Airport| 42.78175|  -71.51478| 199| -4|  A|     F|   null|  null|  null| null|
# |AST|Astoria Regional ...| 46.15797| -123.87869|  15| -8|  A|     F|   null|  null|  null| null|
# |ATK|Atqasuk Edward Bu...|  70.4673|   -157.436|  96| -9|  A|     F|   null|  null|  null| null|
# |ATL|Hartsfield Jackso...| 33.63672|  -84.42807|1026| -5|  A|     F|   null|  null|  null| null|
# |ATT|Camp Mabry Austin...| 30.31666|   -97.7666|   0| -6|  A|     F|   null|  null|  null| null|
# |ATW|            Appleton|44.257526| -88.507576| 680| -6|  A|     F|   null|  null|  null| null|
# |ATY|Watertown Regiona...|   44.914|   -97.1547|1748| -6|  A|     F|   null|  null|  null| null|
# |AUG|       Augusta State| 44.32065|  -69.79732| 352| -5|  A|     F|   null|  null|  null| null|
# |ZRZ|New Carrollton Ra...|   38.948|   -76.8719|  39| -5|  A|     F|   null|  null|  null| null|
# |ZSF|Springfield Amtra...|   42.106| -72.593056|  65| -5|  A|     F|   null|  null|  null| null|
# |ZSY|  Scottsdale Airport| 33.62289| -111.91053|1519| -7|  A|     F|   null|  null|  null| null|
# |ZTF|Stamford Amtrak S...|41.046936|   -73.5415|   0| -5|  A|     F|   null|  null|  null| null|
# |ZTY|Boston Back Bay S...|  42.3478|    -71.075|  20| -5|  A|     F|   null|  null|  null| null|
# |ZUN|          Black Rock| 35.08323| -108.79178|6454| -7|  A|     F|   null|  null|  null| null|
# |ZVE|New Haven Rail St...|41.298668| -72.925995|   7| -5|  A|     F|   null|  null|  null| null|
# |ZWI|Wilmington Amtrak...|39.736668|  -75.55167|   0| -5|  A|     F|   null|  null|  null| null|
# |ZWU|Washington Union ...| 38.89746|  -77.00643|  76| -5|  A|     F|   null|  null|  null| null|
# |ZYP|        Penn Station|  40.7505|   -73.9935|  35| -5|  A|     F|   null|  null|  null| null|
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+------+-----+

# %% [markdown]
# # <center> Pergunta 7

# %%
df_airports = df_airports.withColumn(
    "qa_dst", 
         F.when(F.col("dst").isNull(), "M")
          .when(F.col("dst").rlike("E, A, S, O, Z, N, U"), "C")
          .when(F.col("dst").rlike("\d"), "N")
    )

# %%
df_airports.filter(df_airports.qa_dst.isNotNull()).show()
# Out:
# +---+----+---+---+---+---+---+------+-------+------+------+-----+------+
# |faa|name|lat|lon|alt| tz|dst|qa_faa|qa_name|qa_lat|qa_lon|qa_tz|qa_dst|
# +---+----+---+---+---+---+---+------+-------+------+------+-----+------+
# +---+----+---+---+---+---+---+------+-------+------+------+-----+------+

# %%
df_airports.show()
# Out:
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+------+-----+------+
# |faa|                name|      lat|        lon| alt| tz|dst|qa_faa|qa_name|qa_lat|qa_lon|qa_tz|qa_dst|
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+------+-----+------+
# |04G|   Lansdowne Airport|41.130474|  -80.61958|1044| -5|  A|     F|   null|  null|  null| null|  null|
# |06A|Moton Field Munic...| 32.46057|  -85.68003| 264| -5|  A|     F|   null|  null|  null| null|  null|
# |06C| Schaumburg Regional| 41.98934|  -88.10124| 801| -6|  A|     F|   null|  null|  null| null|  null|
# |06N|     Randall Airport| 41.43191|  -74.39156| 523| -5|  A|     F|   null|  null|  null| null|  null|
# |09J|Jekyll Island Air...|31.074472|  -81.42778|  11| -4|  A|     F|   null|  null|  null| null|  null|
# |0A9|Elizabethton Muni...|36.371223| -82.173416|1593| -4|  A|     F|   null|  null|  null| null|  null|
# |0G6|Williams County A...|41.467304| -84.506775| 730| -5|  A|     F|   null|  null|  null| null|  null|
# |0G7|Finger Lakes Regi...|42.883564| -76.781235| 492| -5|  A|     F|   null|  null|  null| null|  null|
# |0P2|Shoestring Aviati...|39.794823| -76.647194|1000| -5|  U|     F|   null|  null|  null| null|  null|
# |0S9|Jefferson County ...| 48.05381|-122.810646| 108| -8|  A|     F|   null|  null|  null| null|  null|
# |0W3|Harford County Ai...|39.566837|   -76.2024| 409| -5|  A|     F|   null|  null|  null| null|  null|
# |10C|  Galt Field Airport| 42.40289| -88.375114| 875| -6|  U|     F|   null|  null|  null| null|  null|
# |17G|Port Bucyrus-Craw...|40.781555|  -82.97481|1003| -5|  A|     F|   null|  null|  null| null|  null|
# |19A|Jackson County Ai...|34.175865|   -83.5616| 951| -4|  U|     F|   null|  null|  null| null|  null|
# |1A3|Martin Campbell F...|35.015804|  -84.34683|1789| -4|  A|     F|   null|  null|  null| null|  null|
# |1B9| Mansfield Municipal|42.000134|  -71.19677| 122| -5|  A|     F|   null|  null|  null| null|  null|
# |1C9|Frazier Lake Airpark|54.013332| -124.76833| 152| -8|  A|     F|   null|  null|  null| null|  null|
# |1CS|Clow Internationa...|41.695976| -88.129234| 670| -6|  U|     F|   null|  null|  null| null|  null|
# |1G3|  Kent State Airport| 41.15139|  -81.41511|1134| -4|  A|     F|   null|  null|  null| null|  null|
# |1OH|     Fortman Airport|40.555325|  -84.38662| 885| -5|  U|     F|   null|  null|  null| null|  null|
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+------+-----+------+
# only showing top 20 rows

# %%
df_airports = df_airports.drop('name', 'lat', 'lon', 'alt', 'tz', 'dst')

# %%
df_airports.show()
# Out:
# +---+------+-------+------+------+-----+------+
# |faa|qa_faa|qa_name|qa_lat|qa_lon|qa_tz|qa_dst|
# +---+------+-------+------+------+-----+------+
# |04G|     F|   null|  null|  null| null|  null|
# |06A|     F|   null|  null|  null| null|  null|
# |06C|     F|   null|  null|  null| null|  null|
# |06N|     F|   null|  null|  null| null|  null|
# |09J|     F|   null|  null|  null| null|  null|
# |0A9|     F|   null|  null|  null| null|  null|
# |0G6|     F|   null|  null|  null| null|  null|
# |0G7|     F|   null|  null|  null| null|  null|
# |0P2|     F|   null|  null|  null| null|  null|
# |0S9|     F|   null|  null|  null| null|  null|
# |0W3|     F|   null|  null|  null| null|  null|
# |10C|     F|   null|  null|  null| null|  null|
# |17G|     F|   null|  null|  null| null|  null|
# |19A|     F|   null|  null|  null| null|  null|
# |1A3|     F|   null|  null|  null| null|  null|
# |1B9|     F|   null|  null|  null| null|  null|
# |1C9|     F|   null|  null|  null| null|  null|
# |1CS|     F|   null|  null|  null| null|  null|
# |1G3|     F|   null|  null|  null| null|  null|
# |1OH|     F|   null|  null|  null| null|  null|
# +---+------+-------+------+------+-----+------+
# only showing top 20 rows

# %% [markdown]
# # Salvando o arquivo em parquet

# %%
(df_airports
.repartition(1) # coalesce
.write.format("parquet")
.mode('overwrite')
.option("header", "true")
.save("../data/airports_qa.parquet"))

# %% [markdown]
# # <center> DATASET PLANES

# %% [markdown]
# # <center> Pergunta 1

# %%
df_planes = df_planes.withColumn(
    'qa_tailnum', (
        F.when(
            (F.col('tailnum').isNull() | 
             (F.col('tailnum') == '') | 
             F.col('tailnum').rlike(REGEX_EMPTY_STR)), 'M'
        )
        .when(~F.length(F.col('tailnum')).between(5, 6), 'S')
        .when(~F.col('tailnum').startswith('N'), 'FN')
        .when( F.col('tailnum').rlike(REGEX_NNUMBER_INVALID), 'FE')
        .when(~F.col('tailnum').rlike(REGEX_NNUMBER), 'F')
        )
    )

# %%
df_planes = df_planes.withColumn(
    "qa_tailnum", 
        F.when(df_planes["tailnum"].isNull(), "M")
         .when(F.length(df_planes.tailnum) != 6, "S")
         .when(~df_planes["tailnum"].rlike("(^N)"), "FN")
         .when(df_planes["tailnum"].rlike("^[I|0|O]"), "FE")
         .when(~df_planes["tailnum"].rlike("^N([0-9]{1,4})([A-Z]{1,2}$)"), "F")
    )

# %%
df_planes.select(F.count(df_planes.qa_tailnum)).show()
df_planes.select(F.count(df_planes.qa_tailnum.isNull())).show()
df_planes.count()
# Out:
# +-----------------+
# |count(qa_tailnum)|
# +-----------------+
# |              300|
# +-----------------+
#
# +---------------------------+
# |count((qa_tailnum IS NULL))|
# +---------------------------+
# |                       2628|
# +---------------------------+
# 2628

# %%
df_planes.show(2630)
# Out:
# +-------+----+--------------------+--------------------+--------------+-------+-----+-----+-------------+----------+
# |tailnum|year|                type|        manufacturer|         model|engines|seats|speed|       engine|qa_tailnum|
# +-------+----+--------------------+--------------------+--------------+-------+-----+-----+-------------+----------+
# | N102UW|1998|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-214|      2|  182| null|    Turbo-fan|      null|
# | N103US|1999|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-214|      2|  182| null|    Turbo-fan|      null|
# | N104UW|1999|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-214|      2|  182| null|    Turbo-fan|      null|
# | N105UW|1999|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-214|      2|  182| null|    Turbo-fan|      null|
# | N107US|1999|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-214|      2|  182| null|    Turbo-fan|      null|
# | N108UW|1999|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-214|      2|  182| null|    Turbo-fan|      null|
# | N109UW|1999|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-214|      2|  182| null|    Turbo-fan|      null|
# | N110UW|1999|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-214|      2|  182| null|    Turbo-fan|      null|
# | N111US|1999|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-214|      2|  182| null|    Turbo-fan|      null|
# | N11206|2000|Fixed wing multi ...|              BOEING|       737-824|      2|  149| null|    Turbo-fan|         F|
# | N112US|1999|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-214|      2|  182| null|    Turbo-fan|      null|
# | N113UW|1999|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-214|      2|  182| null|    Turbo-fan|      null|
# | N114UW|1999|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-214|      2|  182| null|    Turbo-fan|      null|
# | N155UW|2013|Fixed wing multi ...|              AIRBUS|      A321-211|      2|  199| null|    Turbo-fan|      null|
# | N156DL|1991|Fixed wing multi ...|              BOEING|       767-3P6|      2|  290| null|    Turbo-fan|      null|
# | N156UW|2013|Fixed wing multi ...|              AIRBUS|      A321-211|      2|  199| null|    Turbo-fan|      null|
# | N15710|1998|Fixed wing multi ...|              BOEING|       737-724|      2|  149| null|    Turbo-jet|         F|
# | N15712|1998|Fixed wing multi ...|              BOEING|       737-724|      2|  149| null|    Turbo-jet|         F|
# | N157UW|2013|Fixed wing multi ...|              AIRBUS|      A321-211|      2|  199| null|    Turbo-fan|      null|
# |  N1602|1999|Fixed wing multi ...|              BOEING|       767-332|      2|  330| null|    Turbo-fan|         S|
# |  N1603|1999|Fixed wing multi ...|              BOEING|       767-332|      2|  330| null|    Turbo-fan|         S|
# | N1604R|1999|Fixed wing multi ...|              BOEING|       767-332|      2|  330| null|    Turbo-fan|      null|
# |  N1605|1999|Fixed wing multi ...|              BOEING|       767-332|      2|  330| null|    Turbo-fan|         S|
# | N16065|1999|Fixed wing multi ...|              BOEING|       767-332|      2|  330| null|    Turbo-fan|         F|
# | N1607B|2000|Fixed wing multi ...|              BOEING|       767-332|      2|  330| null|    Turbo-fan|      null|
# |  N1608|2000|Fixed wing multi ...|              BOEING|       767-332|      2|  330| null|    Turbo-fan|         S|
# |  N1609|2000|Fixed wing multi ...|              BOEING|       767-332|      2|  330| null|    Turbo-fan|         S|
# | N1610D|2000|Fixed wing multi ...|              BOEING|       767-332|      2|  330| null|    Turbo-fan|      null|
# | N1611B|2000|Fixed wing multi ...|              BOEING|       767-332|      2|  330| null|    Turbo-fan|      null|
# | N1612T|2001|Fixed wing multi ...|              BOEING|       767-332|      2|  330| null|    Turbo-fan|      null|
# | N1613B|2001|Fixed wing multi ...|              BOEING|       767-332|      2|  330| null|    Turbo-fan|      null|
# | N161PQ|2008|Fixed wing multi ...|      BOMBARDIER INC|   CL-600-2D24|      2|   95| null|    Turbo-fan|      null|
# | N161UW|2001|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A321-211|      2|  199| null|    Turbo-jet|      null|
# | N16217|1998|Fixed wing multi ...|              BOEING|       737-824|      2|  149| null|    Turbo-fan|         F|
# | N16234|1999|Fixed wing multi ...|              BOEING|       737-824|      2|  149| null|    Turbo-fan|         F|
# | N162PQ|2008|Fixed wing multi ...|      BOMBARDIER INC|   CL-600-2D24|      2|   95| null|    Turbo-fan|      null|
# | N162UW|2001|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A321-211|      2|  199| null|    Turbo-jet|      null|
# | N163US|2001|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A321-211|      2|  199| null|    Turbo-jet|      null|
# | N165US|2001|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A321-211|      2|  199| null|    Turbo-jet|      null|
# | N16701|1998|Fixed wing multi ...|              BOEING|       737-724|      2|  149| null|    Turbo-jet|         F|
# | N16703|1998|Fixed wing multi ...|              BOEING|       737-724|      2|  149| null|    Turbo-jet|         F|
# | N295SW|1996|Fixed wing multi ...|             EMBRAER|     EMB-120ER|      2|   32| null|   Turbo-prop|      null|
# | N295WN|2007|Fixed wing multi ...|              BOEING|       737-7H4|      2|  140| null|    Turbo-fan|      null|
# | N296SW|1996|Fixed wing multi ...|             EMBRAER|     EMB-120ER|      2|   32| null|   Turbo-prop|      null|
# | N296WN|2007|Fixed wing multi ...|              BOEING|       737-7H4|      2|  140| null|    Turbo-fan|      null|
# | N29717|1999|Fixed wing multi ...|              BOEING|       737-724|      2|  149| null|    Turbo-jet|         F|
# | N297SW|1996|Fixed wing multi ...|             EMBRAER|     EMB-120ER|      2|   32| null|   Turbo-prop|      null|
# | N297WN|2007|Fixed wing multi ...|              BOEING|       737-7H4|      2|  140| null|    Turbo-fan|      null|
# | N298SW|1996|Fixed wing multi ...|             EMBRAER|     EMB-120ER|      2|   32| null|   Turbo-prop|      null|
# | N298WN|null|Fixed wing multi ...|              BOEING|       737-7H4|      2|  140| null|    Turbo-fan|      null|
# | N299SW|1997|Fixed wing multi ...|             EMBRAER|     EMB-120ER|      2|   32| null|   Turbo-prop|      null|
# | N299WN|null|Fixed wing multi ...|              BOEING|       737-7H4|      2|  140| null|    Turbo-fan|      null|
# | N301NB|1999|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A319-114|      2|  145| null|    Turbo-fan|      null|
# | N302AS|2003|Fixed wing multi ...|              BOEING|       737-990|      2|  149| null|    Turbo-jet|      null|
# | N302DQ|2008|Fixed wing multi ...|              BOEING|       737-732|      2|  149| null|    Turbo-fan|      null|
# | N302NB|1999|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A319-114|      2|  145| null|    Turbo-fan|      null|
# | N303AS|2001|Fixed wing multi ...|              BOEING|       737-990|      2|  149| null|    Turbo-jet|      null|
# | N30401|2001|Fixed wing multi ...|              BOEING|       737-924|      2|  191| null|    Turbo-fan|         F|
# | N305AS|2001|Fixed wing multi ...|              BOEING|       737-990|      2|  149| null|    Turbo-jet|      null|
# | N306AS|2001|Fixed wing multi ...|              BOEING|       737-990|      2|  149| null|    Turbo-jet|      null|
# | N306DQ|2009|Fixed wing multi ...|              BOEING|       737-732|      2|  149| null|    Turbo-fan|      null|
# | N307AS|2001|Fixed wing multi ...|              BOEING|       737-990|      2|  149| null|    Turbo-jet|      null|
# | N309AS|2001|Fixed wing multi ...|              BOEING|       737-990|      2|  149| null|    Turbo-jet|      null|
# | N309US|1990|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# | N310NW|1990|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# | N311US|1990|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# | N312US|1990|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# | N313US|1990|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# | N31412|2002|Fixed wing multi ...|              BOEING|       737-924|      2|  191| null|    Turbo-fan|         F|
# | N314NB|2000|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A319-114|      2|  145| null|    Turbo-fan|      null|
# | N314US|1991|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# | N315AS|2002|Fixed wing multi ...|              BOEING|       737-990|      2|  149| null|    Turbo-jet|      null|
# | N315NB|2000|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A319-114|      2|  145| null|    Turbo-fan|      null|
# | N315US|1991|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# | N316NB|2000|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A319-114|      2|  145| null|    Turbo-fan|      null|
# | N316US|1991|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# | N317AS|2003|Fixed wing multi ...|              BOEING|       737-990|      2|  149| null|    Turbo-jet|      null|
# | N317NB|2000|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A319-114|      2|  145| null|    Turbo-fan|      null|
# | N317US|1991|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# | N317WN|1988|Fixed wing multi ...|              BOEING|       737-3Q8|      2|  149| null|    Turbo-fan|      null|
# | N318AS|2003|Fixed wing multi ...|              BOEING|       737-990|      2|  149| null|    Turbo-jet|      null|
# | N318NB|2000|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A319-114|      2|  145| null|    Turbo-fan|      null|
# | N318US|1991|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# | N319AS|2003|Fixed wing multi ...|              BOEING|       737-990|      2|  149| null|    Turbo-jet|      null|
# | N319NB|2000|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A319-114|      2|  145| null|    Turbo-fan|      null|
# | N319US|1991|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# | N320AS|2003|Fixed wing multi ...|              BOEING|       737-990|      2|  149| null|    Turbo-jet|      null|
# | N320NB|2000|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A319-114|      2|  145| null|    Turbo-fan|      null|
# | N320US|1991|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# | N321NB|2001|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A319-114|      2|  145| null|    Turbo-fan|      null|
# | N321US|1992|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# | N322NB|2001|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A319-114|      2|  145| null|    Turbo-fan|      null|
# | N322US|1992|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# | N323AS|2004|Fixed wing multi ...|              BOEING|       737-990|      2|  149| null|    Turbo-jet|      null|
# | N323NB|2001|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A319-114|      2|  145| null|    Turbo-fan|      null|
# | N323US|1992|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# | N32404|2001|Fixed wing multi ...|              BOEING|       737-924|      2|  191| null|    Turbo-fan|         F|
# | N324NB|2001|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A319-114|      2|  145| null|    Turbo-fan|      null|
# | N324US|1992|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# | N325NB|2001|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A319-114|      2|  145| null|    Turbo-fan|      null|
# | N325US|1992|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# | N326NB|2001|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A319-114|      2|  145| null|    Turbo-fan|      null|
# | N326US|1992|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# | N327NB|2001|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A319-114|      2|  145| null|    Turbo-fan|      null|
# | N327NW|1992|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# | N328NW|1992|Fixed wing multi ...|    AIRBUS INDUSTRIE|      A320-211|      2|  182| null|    Turbo-jet|      null|
# ...
# | N931WN|2009|Fixed wing multi ...|              BOEING|       737-7H4|      2|  140| null|    Turbo-fan|      null|
# | N932DN|1996|Fixed wing multi ...|   MCDONNELL DOUGLAS|      MD-90-30|      2|  142| null|    Turbo-jet|      null|
# | N932EV|2005|Fixed wing multi ...|      BOMBARDIER INC|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# | N932FR|2004|Fixed wing multi ...|              AIRBUS|      A319-111|      2|  147| null|    Turbo-fan|      null|
# | N932SW|2002|Fixed wing multi ...|      BOMBARDIER INC|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# | N932WN|2009|Fixed wing multi ...|              BOEING|       737-7H4|      2|  140| null|    Turbo-fan|      null|
# | N933DN|1997|Fixed wing multi ...|   MCDONNELL DOUGLAS|      MD-90-30|      2|  142| null|    Turbo-jet|      null|
# | N933FR|2004|Fixed wing multi ...|              AIRBUS|      A319-111|      2|  147| null|    Turbo-fan|      null|
# | N933WN|2009|Fixed wing multi ...|              BOEING|       737-7H4|      2|  140| null|    Turbo-fan|      null|
# | N934DN|1996|Fixed wing multi ...|   MCDONNELL DOUGLAS|      MD-90-30|      2|  142| null|    Turbo-fan|      null|
# | N934FR|2004|Fixed wing multi ...|              AIRBUS|      A319-111|      2|  147| null|    Turbo-fan|      null|
# | N934SW|2002|Fixed wing multi ...|      BOMBARDIER INC|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# | N967SW|2003|Fixed wing multi ...|      BOMBARDIER INC|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# | N967WN|2011|Fixed wing multi ...|              BOEING|       737-7H4|      2|  140| null|    Turbo-fan|      null|
# | N968WN|2011|Fixed wing multi ...|              BOEING|       737-7H4|      2|  140| null|    Turbo-fan|      null|
# | N969SW|2003|Fixed wing multi ...|      BOMBARDIER INC|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# | N969WN|2011|Fixed wing multi ...|              BOEING|       737-7H4|      2|  140| null|    Turbo-fan|      null|
# | N970SW|2003|Fixed wing multi ...|      BOMBARDIER INC|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# | N971SW|2004|Fixed wing multi ...|      BOMBARDIER INC|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# | N971UY|null|Fixed wing multi ...|              AIRBUS|      A321-231|      2|  379| null|    Turbo-fan|      null|
# | N973SW|2004|Fixed wing multi ...|      BOMBARDIER INC|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# | N975SW|2004|Fixed wing multi ...|      BOMBARDIER INC|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# | N976SW|2004|Fixed wing multi ...|      BOMBARDIER INC|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# | N978SW|2004|Fixed wing multi ...|      BOMBARDIER INC|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# | N979SW|2004|Fixed wing multi ...|      BOMBARDIER INC|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# | N980SW|2004|Fixed wing multi ...|      BOMBARDIER INC|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# | N982SW|2004|Fixed wing multi ...|      BOMBARDIER INC|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# | N983CA|1997|Fixed wing multi ...|            CANADAIR|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# | N983SW|2004|Fixed wing multi ...|      BOMBARDIER INC|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# | N984CA|1997|Fixed wing multi ...|            CANADAIR|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# | N986CA|null|Fixed wing multi ...|            CANADAIR|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# | N986SW|2004|Fixed wing multi ...|      BOMBARDIER INC|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# | N988CA|1997|Fixed wing multi ...|            CANADAIR|   CL-600-2B19|      2|   55| null|    Turbo-fan|      null|
# +-------+----+--------------------+--------------------+--------------+-------+-----+-----+-------------+----------+

# %%
df_planes = df_planes.withColumn(
    'qa_tailnum',
        F.when((F.col('tailnum').isNull()), "M")
        .when((F.length(F.col('tailnum')) != 5) & (F.length(F.col('tailnum')) != 6), "S") 
        .when((F.col('tailnum').rlike("^N([0-9]{1,4})([A-Z]{1,2}$)") == False), "F")
        .when((F.col('tailnum').rlike("^N") == False), "FN")
        .when((F.col('tailnum').rlike("^[IO0]") == True), "FE")
    )

# %% [markdown]
# # <center> Pergunta 2

# %%
df_planes = df_planes.withColumn(
    "qa_year",
         F.when((F.col("year").isNull()), "M")
         .when((F.col("year") < 1950), "I")
    )

# %% [markdown]
# # <center> Pergunta 3

# %%
category = ["Fixed wing multi engine","Fixed wing single engine","Rotorcraft"]
df_planes = df_planes.withColumn(
    "qa_type",
        F.when((F.col('type').isNull()), "M")
        .when(~(F.col('type').isin(category)), "C")
    )

# %% [markdown]
# # <center> Pergunta 4

# %%
category = ["AIRBUS", "BOEING", "BOMBARDIER", "CESSNA", "EMBRAER",
            "SIKORSKY", "CANADAIR", "PIPER", "MCDONNELL DOUGLAS", "CIRRUS",
            "BELL", "KILDALL GARY", "LAMBERT RICHARD", "BARKER JACK",
            "ROBINSON HELICOPTER", "GULFSTREAM", "MARZ BARRY"]
df_planes = df_planes.withColumn(
    "qa_manufacturer",
        F.when((F.col("manufacturer").isNull()), "M")
        .when(~(F.col("manufacturer").isin(category)), "C")
    )

# %% [markdown]
# # <center> Pergunta 5

# %%
df_planes = df_planes.withColumn(
    "qa_model",
         F.when((F.col("model").isNull()), "M")
         .when(
             (F.col("manufacturer") == "AIRBUS") & 
             (~F.col("model").rlike("^A")),
             "F")
         .when(
             (F.col("manufacturer") =="BOEING") & 
             (~F.col("model").rlike("^7")),
             "F")
         .when(
             (F.col("manufacturer") == "BOMBARDIER") | 
             (F.col("manufacturer") == "CANADAIR") &
             (~F.col("model").rlike("^CL")),
              "F")
         .when(
             (F.col("manufacturer") == "MCDONNELL DOUGLAS") &
             (~F.col("model").rlike("^(MD|DC)")),
             "F")
     )

# %%
df_planes = df_planes.withColumn(
    "qa_model",
         F.when((F.col("model").isNull()), "M")
         .when(
             (F.col("manufacturer") == "AIRBUS") & 
             (~F.col("model").rlike("^A")),
             "F")
         .when(
             (F.col("manufacturer") =="BOEING") & 
             (~F.col("model").rlike("^7")),
             "F")
         .when(
             (F.col("manufacturer") == "BOMBARDIER") | 
             (F.col("manufacturer") == "CANADAIR") &
             (~F.col("model").rlike("^CL")),
             "F")
         .when(
             (F.col("manufacturer") == "MCDONNELL DOUGLAS") &
              ~(
                  F.col("model").rlike("^MD") |
                 (F.col("model").rlike("^DC"))
              ),
             "F")
     )

# %% [markdown]
# # <center> Pergunta 6

# %%
df_planes = df_planes.withColumn(
    "qa_engines",
        F.when((F.col("engines").isNull()), "M")
        .when(~(F.col("engines").between(1,4)), "I")
        .when((F.col("engines").rlike("\n")), "A")
    )

# %% [markdown]
# # <center> Pergunta 7

# %%
df_planes = df_planes.withColumn(
    "qa_seats",
        F.when((F.col("seats").isNull()), "M")
        .when(~(F.col("seats").between(2,500)), "I")
        .when((F.col("seats").rlike("\n")), "A")
    )

# %% [markdown]
# # <center> Pergunta 8

# %%
df_planes = df_planes.withColumn(
    "qa_speed",
        F.when((F.col("speed").isNull()), "M")
        .when(~(F.col("speed").between(50,150)), "I")
        .when(~(F.col("speed").rlike("\w")), "A")
    )

# %% [markdown]
# # <center> Pergunta 9

# %%
category = ["Turbo-fan","Turbo-jet","Turbo-prop","Turbo-shaft","4 Cycle"]
df_planes = df_planes.withColumn(
    "qa_engine",
        F.when((F.col("engine").isNull()), "M")
        .when(~(F.col("engine").isin(category)), "C")
    )

# %%
df_planes_final = df_planes.drop('year','type','manufacturer','model','engines','seats','speed','engine')
df_planes_final.show()
# Out:
# +-------+----------+-------+--------+----------+--------+--------+---------+
# |tailnum|qa_tailnum|qa_year|qa_model|qa_engines|qa_seats|qa_speed|qa_engine|
# +-------+----------+-------+--------+----------+--------+--------+---------+
# | N102UW|      null|   null|    null|      null|    null|       M|     null|
# | N103US|      null|   null|    null|      null|    null|       M|     null|
# | N104UW|      null|   null|    null|      null|    null|       M|     null|
# | N105UW|      null|   null|    null|      null|    null|       M|     null|
# | N107US|      null|   null|    null|      null|    null|       M|     null|
# | N108UW|      null|   null|    null|      null|    null|       M|     null|
# | N109UW|      null|   null|    null|      null|    null|       M|     null|
# | N110UW|      null|   null|    null|      null|    null|       M|     null|
# | N111US|      null|   null|    null|      null|    null|       M|     null|
# | N11206|         F|   null|    null|      null|    null|       M|     null|
# | N112US|      null|   null|    null|      null|    null|       M|     null|
# | N113UW|      null|   null|    null|      null|    null|       M|     null|
# | N114UW|      null|   null|    null|      null|    null|       M|     null|
# | N117UW|      null|   null|    null|      null|    null|       M|     null|
# | N118US|      null|   null|    null|      null|    null|       M|     null|
# | N119US|      null|   null|    null|      null|    null|       M|     null|
# | N1200K|      null|   null|    null|      null|    null|       M|     null|
# | N1201P|      null|   null|    null|      null|    null|       M|     null|
# | N12114|         F|   null|    null|      null|    null|       M|     null|
# | N121DE|      null|   null|    null|      null|    null|       M|     null|
# +-------+----------+-------+--------+----------+--------+--------+---------+
# only showing top 20 rows

# %%
(df_planes_final
.repartition(1) # coalesce
.write.format("parquet")
.mode('overwrite')
.option("header", "true")
.save("../data/planes_qa.parquet"))

# %%
df_planes_final.groupby('qa_tailnum').count().show()
df_planes_final.groupby('qa_year').count().show()
df_planes_final.groupby('qa_type').count().show()
df_planes_final.groupby('qa_manufacturer').count().show()
df_planes_final.groupby('qa_model').count().show()
df_planes_final.groupby('qa_seats').count().show()
df_planes_final.groupby('qa_speed').count().show()
df_planes_final.groupby('qa_engine').count().show()
df_planes_final.groupby('qa_engines').count().show()
# Out:
# +----------+-----+
# |qa_tailnum|count|
# +----------+-----+
# |         F|  298|
# |      null| 2330|
# +----------+-----+
#
# +-------+-----+
# |qa_year|count|
# +-------+-----+
# |   null| 2567|
# |      M|   60|
# |      I|    1|
# +-------+-----+
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34732/322430933.py in <module>
#       1 df_planes_final.groupby('qa_tailnum').count().show()
#       2 df_planes_final.groupby('qa_year').count().show()
# ----> 3 df_planes_final.groupby('qa_type').count().show()
#       4 df_planes_final.groupby('qa_manufacturer').count().show()
#       5 df_planes_final.groupby('qa_model').count().show()
#
# C:\spark-3.2.1-bin-hadoop2.7\python\pyspark\sql\group.py in _api(self)
#      29     def _api(self):
#      30         name = f.__name__
# ---> 31         jdf = getattr(self._jgd, name)()
#      32         return DataFrame(jdf, self.sql_ctx)
#      33     _api.__name__ = f.__name__
#
# C:\spark-3.2.1-bin-hadoop2.7\python\lib\py4j-0.10.9.3-src.zip\py4j\java_gateway.py in __call__(self, *args)
#    1319
#    1320         answer = self.gateway_client.send_command(command)
# -> 1321         return_value = get_return_value(
#    1322             answer, self.gateway_client, self.target_id, self.name)
#    1323
#
# C:\spark-3.2.1-bin-hadoop2.7\python\pyspark\sql\utils.py in deco(*a, **kw)
#     115                 # Hide where the exception came from that shows a non-Pythonic
#     116                 # JVM exception message.
# --> 117                 raise converted from None
#     118             else:
#     119                 raise
#
# AnalysisException: cannot resolve 'qa_type' given input columns: [qa_engine, qa_engines, qa_model, qa_seats, qa_speed, qa_tailnum, qa_year, tailnum];
# 'Aggregate ['qa_type], ['qa_type, count(1) AS count#430L]
# +- Project [tailnum#14, qa_tailnum#213, qa_year#224, qa_model#249, qa_engines#262, qa_seats#276, qa_speed#291, qa_engine#307]
#    +- Project [tailnum#14, year#15, type#16, manufacturer#17, model#18, engines#19, seats#20, speed#21, engine#22, qa_tailnum#213, qa_year#224, qa_model#249, qa_engines#262, qa_seats#276, qa_speed#291, CASE WHEN isnull(engine#22) THEN M WHEN NOT engine#22 IN (Turbo-fan,Turbo-jet,Turbo-prop,Turbo-shaft,4 Cycle) THEN C END AS qa_engine#307]
#       +- Project [tailnum#14, year#15, type#16, manufacturer#17, model#18, engines#19, seats#20, speed#21, engine#22, qa_tailnum#213, qa_year#224, qa_model#249, qa_engines#262, qa_seats#276, CASE WHEN isnull(speed#21) THEN M WHEN NOT ((speed#21 >= 50) AND (speed#21 <= 150)) THEN I WHEN NOT RLIKE(cast(speed#21 as string), \w) THEN A END AS qa_speed#291]
#          +- Project [tailnum#14, year#15, type#16, manufacturer#17, model#18, engines#19, seats#20, speed#21, engine#22, qa_tailnum#213, qa_year#224, qa_model#249, qa_engines#262, CASE WHEN isnull(seats#20) THEN M WHEN NOT ((seats#20 >= 2) AND (seats#20 <= 500)) THEN I WHEN RLIKE(cast(seats#20 as string),
# ) THEN A END AS qa_seats#276]
#             +- Project [tailnum#14, year#15, type#16, manufacturer#17, model#18, engines#19, seats#20, speed#21, engine#22, qa_tailnum#213, qa_year#224, qa_model#249, CASE WHEN isnull(engines#19) THEN M WHEN NOT ((engines#19 >= 1) AND (engines#19 <= 4)) THEN I WHEN RLIKE(cast(engines#19 as string),
# ) THEN A END AS qa_engines#262]
#                +- Project [tailnum#14, year#15, type#16, manufacturer#17, model#18, engines#19, seats#20, speed#21, engine#22, qa_tailnum#213, qa_year#224, CASE WHEN isnull(model#18) THEN M WHEN ((manufacturer#17 = AIRBUS) AND NOT RLIKE(model#18, ^A)) THEN F WHEN ((manufacturer#17 = BOEING) AND NOT RLIKE(model#18, ^7)) THEN F WHEN ((manufacturer#17 = BOMBARDIER) OR ((manufacturer#17 = CANADAIR) AND NOT RLIKE(model#18, ^CL))) THEN F WHEN ((manufacturer#17 = MCDONNELL DOUGLAS) AND NOT (RLIKE(model#18, ^MD) OR RLIKE(model#18, ^DC))) THEN F END AS qa_model#249]
#                   +- Project [tailnum#14, year#15, type#16, manufacturer#17, model#18, engines#19, seats#20, speed#21, engine#22, qa_tailnum#213, qa_year#224, CASE WHEN isnull(model#18) THEN M WHEN ((manufacturer#17 = AIRBUS) AND NOT RLIKE(model#18, ^A)) THEN F WHEN ((manufacturer#17 = BOEING) AND NOT RLIKE(model#18, ^7)) THEN F WHEN ((manufacturer#17 = BOMBARDIER) OR ((manufacturer#17 = CANADAIR) AND NOT RLIKE(model#18, ^CL))) THEN F WHEN ((manufacturer#17 = MCDONNELL DOUGLAS) AND NOT RLIKE(model#18, ^(MD|DC))) THEN F END AS qa_model#236]
#                      +- Project [tailnum#14, year#15, type#16, manufacturer#17, model#18, engines#19, seats#20, speed#21, engine#22, qa_tailnum#213, CASE WHEN isnull(year#15) THEN M WHEN (year#15 < 1950) THEN I END AS qa_year#224]
#                         +- Project [tailnum#14, year#15, type#16, manufacturer#17, model#18, engines#19, seats#20, speed#21, engine#22, CASE WHEN isnull(tailnum#14) THEN M WHEN (NOT (length(tailnum#14) = 5) AND NOT (length(tailnum#14) = 6)) THEN S WHEN (RLIKE(tailnum#14, ^N([0-9]{1,4})([A-Z]{1,2}$)) = false) THEN F WHEN (RLIKE(tailnum#14, ^N) = false) THEN FN WHEN (RLIKE(tailnum#14, ^[IO0]) = true) THEN FE END AS qa_tailnum#213]
#                            +- Project [tailnum#14, year#15, type#16, manufacturer#17, model#18, engines#19, seats#20, speed#21, engine#22, CASE WHEN isnull(tailnum#14) THEN M WHEN NOT (length(tailnum#14) = 6) THEN S WHEN NOT RLIKE(tailnum#14, (^N)) THEN FN WHEN RLIKE(tailnum#14, ^[I|0|O]) THEN FE WHEN NOT RLIKE(tailnum#14, ^N([0-9]{1,4})([A-Z]{1,2}$)) THEN F END AS qa_tailnum#202]
#                               +- Project [tailnum#14, year#15, type#16, manufacturer#17, model#18, engines#19, seats#20, speed#21, engine#22, CASE WHEN ((isnull(tailnum#14) OR (tailnum#14 = )) OR RLIKE(tailnum#14, [\t ]+$)) THEN M WHEN NOT ((length(tailnum#14) >= 5) AND (length(tailnum#14) <= 6)) THEN S WHEN NOT StartsWith(tailnum#14, N) THEN FN WHEN RLIKE(tailnum#14, (N0.*$)|(.*[IO].*)) THEN FE WHEN NOT RLIKE(tailnum#14, ^N[1-9][0-9]{2,3}([ABCDEFGHJKLMNPRSTUVXWYZ]{1,2})) THEN F END AS qa_tailnum#191]
#                                  +- Relation [tailnum#14,year#15,type#16,manufacturer#17,model#18,engines#19,seats#20,speed#21,engine#22] csv

# %% [markdown]
# # <center> DataSets Flight

# %% [markdown]
# # <center> Pergunta 1

# %%
df_flights = df_flights.withColumn(
    "qa_year_month_day",
        F.when((F.col("year").isNull()), "MY")
        .when((F.col("month").isNull()),"MM")
        .when((F.col("day").isNull()), "MD")
        .when((F.col("year") < 1950), "IY")
        .when(
            (F.col("month") < 1) &
            (F.col("month") > 12),
            "IM")
        .when(
            (~F.col("day").between(1,31)) |
            (F.col("month") == 2) & 
            (~F.col("day").between(1,29)),
            "ID")
    )

# %% [markdown]
# # <center> Pergunta 2

# %%
df_flights = df_flights.withColumn(
    "qa_hour_minute",
        F.when((F.col('hour').isNull()), "MH")
        .when(
            (F.col('hour') < 0) &
            (F.col('hour') > 24),
            "MM")
        .when((F.col('minute').isNull()),"MM")
        .when((~F.col('minute').between(0,59)), "IM")
    )

# %% [markdown]
# # <center> Pergunta 3

# %%
df_flights = df_flights.withColumn(
    "qa_dep_arr_time",
         F.when((F.col("dep_time").isNull()), "MD")
          .when(
              (
                  F.col("arr_time").isNull() & 
                  F.col("arr_time").rlike('([0-9]{1,2})') == True
              ),
              "MA")
          .when(
              ~(F.length(F.col("dep_time")) == 3) &
               (F.col("dep_time").substr(0,1) <= 9) | 
               (F.length(F.col("dep_time")) == 4) & 
               (F.col("dep_time").substr(0,2) <= 24),
              "FD")
          .when(
              (F.length(F.col("arr_time")) == 3) &
              (F.col("arr_time").substr(0,1) <= 9) | 
              (F.length(F.col("arr_time")) == 4) & 
              (F.col("arr_time").substr(0,2) <= 59),
              "FA")
      )

# %% [markdown]
# # <center> Pergunta 4

# %%
df_flights = df_flights.withColumn(
    "qa_dep_arr_delay",
        F.when((F.col("dep_delay").isNull()), "MD")
        .when((F.col("arr_delay").isNull()), "MA")
    )

# %% [markdown]
# # <center> Pergunta 5

# %%
df_flights = df_flights.withColumn(
    "qa_carrier",
         F.when((F.col("carrier").isNull()), "M")
         .when(
             (F.length(F.col("carrier")) != 2) & 
             (F.col("carrier").rlike("\w{1,2}")),
             "F")
     )

# %% [markdown]
# # <center> Pergunta 6

# %%
df_flights = (df_flights.withColumn(
    'qa_tailnum',
        F.when(
            (F.col('tailnum').isNull()) | 
            (F.col('tailnum') == 'NA'),
            "M")
        .when(
            (F.length(F.col('tailnum')) != 5) & 
            (F.length(F.col('tailnum')) != 6),
            "S")
        .when((F.col('tailnum').rlike("^N") == False), "FN")
        .when((F.col('tailnum').rlike("^[IO0]") == True), "FE")
        .when((F.col('tailnum').rlike("^N([0-9]{1,4})([A-Z]{1,2}$)") == False), "F"))
    )

# %% [markdown]
# # <center> Pergunta 7

# %%
df_flights = df_flights.withColumn(
    "qa_flight",
         F.when((F.col("flight").isNull()), "M")
         .when(
             (F.length(F.col("flight")) != 4) & 
             (F.col("flight").rlike("\w{1,4}")),
             "F")
     )

# %% [markdown]
# # <center> Pergunta 8

# %%
df_flights = df_flights.withColumn(
    "origin_dest", 
        F.when((F.col('origin').isNull()), "MO")
        .when((F.col('dest').isNull()), "MD")
        .when((F.col("origin").rlike("\w{3}") == False), "FO")
        .when(~(F.col("dest").rlike("\w{3}")), "FD")
    )

# %% [markdown]
# # <center> Pergunta 9

# %%
df_flights = df_flights.withColumn(
    "qa_air_time",
          F.when((F.col("air_time").isNull()), "M")
          .when((F.col("air_time").between(20,500) == False), "I")
     )

# %% [markdown]
# # <center> Pergunta 10

# %%
df_flights = df_flights.withColumn(
    "qa_distance",
        F.when((F.col("distance").isNull()), "M")
        .when((F.col("distance").between(50,3000) == False), "I")
    )

# %% [markdown]
# # <center> Pergunta 11

# %%
df_flights = df_flights.withColumn(
    "qa_distance_airtime",
        F.when(
            (F.col("distance").isNull()) |
            (F.col("air_time").isNull()),
            "M")
        .when((F.col("air_time")) >= ((F.col("distance") * 0.1) + 30), "TL")
        .when((F.col("air_time")) <= ((F.col("distance") * 0.1) + 10), "TS")
    .otherwise("TR")
    )

# %%
df_flights_final = df_flights.drop('year','month','day','dep_time','dep_delay','arr_time','carrier','flight','air_time','distance','hour','minute','arr_delay')

# %%
(df_flights_final
.repartition(1) # coalesce
.write.format("parquet")
.mode('overwrite')
.option("header", "true")
.save("../data/flights_qa.parquet"))

# %%
df_flights_final.groupBy('qa_year_month_day').count().show()
df_flights_final.groupBy('qa_hour_minute').count().show()
df_flights_final.groupBy('qa_dep_arr_time').count().show()
df_flights_final.groupBy('qa_dep_arr_delay').count().show()
df_flights_final.groupBy('qa_carrier').count().show()
df_flights_final.groupBy('qa_tailnum').count().show()
df_flights_final.groupBy('qa_flight').count().show()
df_flights_final.groupBy('origin_dest').count().show()
df_flights_final.groupBy('qa_air_time').count().show()
df_flights_final.groupBy('qa_distance').count().show()
df_flights_final.groupBy('qa_distance_airtime').count().show()
# Out:
# +-----------------+-----+
# |qa_year_month_day|count|
# +-----------------+-----+
# |             null|10000|
# +-----------------+-----+
#
# +--------------+-----+
# |qa_hour_minute|count|
# +--------------+-----+
# |          null| 9952|
# |            MH|   48|
# +--------------+-----+
#
# +---------------+-----+
# |qa_dep_arr_time|count|
# +---------------+-----+
# |           null|   50|
# |             FA| 3173|
# |             FD| 6777|
# +---------------+-----+
#
# +----------------+-----+
# |qa_dep_arr_delay|count|
# +----------------+-----+
# |            null| 9925|
# |              MD|   48|
# |              MA|   27|
# +----------------+-----+
#
# +----------+-----+
# |qa_carrier|count|
# +----------+-----+
# |      null|10000|
# +----------+-----+
#
# +----------+-----+
# |qa_tailnum|count|
# +----------+-----+
# |         F|  987|
# |      null| 8997|
# |         M|   14|
# |        FN|    2|
# +----------+-----+
#
# +---------+-----+
# |qa_flight|count|
# +---------+-----+
# |        F| 6158|
# |     null| 3842|
# +---------+-----+
#
# +-----------+-----+
# |origin_dest|count|
# +-----------+-----+
# |       null|10000|
# +-----------+-----+
#
# +-----------+-----+
# |qa_air_time|count|
# +-----------+-----+
# |       null| 9925|
# |          M|   75|
# +-----------+-----+
#
# +-----------+-----+
# |qa_distance|count|
# +-----------+-----+
# |       null|10000|
# +-----------+-----+
#
# +-------------------+-----+
# |qa_distance_airtime|count|
# +-------------------+-----+
# |                  M|   75|
# |                 TR| 4831|
# |                 TS|   67|
# |                 TL| 5027|
# +-------------------+-----+
